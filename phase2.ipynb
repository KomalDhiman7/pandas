# %%
import pandas as pd
import numpy as np
data = pd.read_csv('matches - matches.csv')

# %% [markdown]
# ### series

# %%
data['winner'].value_counts().head(5)  # use head or tail for top 5 values and if head tail not use not an issue
# Out:
# winner
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Name: count, dtype: int64

# %%
myseries= data['winner'].value_counts()
myseries['Kings XI Punjab']
# Out:
# np.int64(70)

# %%
data['team1'].value_counts()  
data['team2'].value_counts()

data['team2'].value_counts()+data['team1'].value_counts()  # total matchs
# Out:
# Chennai Super Kings            131
# Deccan Chargers                 75
# Delhi Daredevils               147
# Gujarat Lions                   30
# Kings XI Punjab                148
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          148
# Mumbai Indians                 157
# Pune Warriors                   46
# Rajasthan Royals               118
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    152
# Sunrisers Hyderabad             76
# Name: count, dtype: int64

# %% [markdown]
# ### Sorting

# %%
(data['team2'].value_counts()+data['team1'].value_counts()).sort_values().head(5)  
# or
(data['team2'].value_counts()+data['team1'].value_counts()).sort_values(ascending= False)  #bydefault its true but false will descend the values
(data['team2'].value_counts()+data['team1'].value_counts()).sort_values(ascending= False, inplace= True) # implace = true will save the cahnges permanently
myseries
# Out:
# winner
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: count, dtype: int64

# %%
data.sort_values(['city', 'date'], ascending = [True,False], inplace= True) #city will be in ascending order and date in descending order
data
# Out:
#       id  season       city        date                        team1  \
# 475  476    2014  Abu Dhabi  2014-04-29             Rajasthan Royals
# 470  471    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# 471  472    2014  Abu Dhabi  2014-04-26              Kings XI Punjab
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 459  460    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
# ..   ...     ...        ...         ...                          ...
# 468  469    2014        NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014        NaN  2014-04-25               Mumbai Indians
# 466  467    2014        NaN  2014-04-23          Chennai Super Kings
# 461  462    2014        NaN  2014-04-19               Mumbai Indians
# 462  463    2014        NaN  2014-04-19        Kolkata Knight Riders
#
#                            team2                  toss_winner toss_decision  \
# ...
